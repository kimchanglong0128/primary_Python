# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\\Users\\jinchanglong\\Desktop\\LAM_INFO.csv")

df1 = df.iloc[:13]    ###切前13行 ， 所有的列
df2 = df.loc[:13]     ###切前13行 ， 所有的列

df.head(100000)
# Out:
#           BASE_ID 01_LAMINATION_LOT_ID 01_LAMINATION_EQP_ID  \
# 0      UAGI53LMC2           UAGI53LMC2            N3ALAMM18
# 1      UAGI72LMC1           UAGI72LMC1            N3ALAMM29
# 2      UAGG71LMC1           UAGG71LMC1            N3ALAMM28
# 3      UAGH72LMC3           UAGH72LMC3            N3ALAMM29
# 4      UAGG51LMC2           UAGG51LMC2            N3ALAMM16
# ...           ...                  ...                  ...
# 99995  UAGJ53LMC1           UAGJ53LMC1            N3ALAMM18
# 99996  UAGKE4LMC1           UAGKE4LMC1            N3ALAMM26
# 99997  UAGF52LMC2           UAGF52LMC2            N3ALAMM17
# 99998  UAGG72LMC1           UAGG72LMC1            N3ALAMM29
# 99999  UAGHE5LMC1           UAGHE5LMC1            N3ALAMM27
#
#       01_LAMINATION_CELL_ID    01_LAMINATION_WK_DTM  \
# 0                BBHJ0013aI   2021-07-19 오후 5:12:04
# 1                NBHI0410Ja   2021-07-19 오전 6:06:15
# 2                PBHG00606B  2021-07-16 오후 12:15:56
# ...

# %%
import time
d = pd.read_csv("C:\\Users\\jinchanglong\\Desktop\\LAM_INFO.csv", 
                usecols=['01_LAMINATION_LOT_ID','01_LAMINATION_CELL_ID','03_PACKAGING_LOT_ID','01_LAMINATION_WK_DTM'],###提取哪一列
                nrows=10,
               index_col = 2)                                                                      ###提取多少行

#d['01_LAMINATION_WK_DTM'] = d['01_LAMINATION_WK_DTM'].str.replace('오후','PM')
#d['01_LAMINATION_WK_DTM'] = d['01_LAMINATION_WK_DTM'].str.replace('오전','AM')

#d['01_LAMINATION_WK_DTM']

# %%
import pandas as pd 
import numpy as np

df = pd.read_excel(r"C:\Users\jinchanglong\Desktop\E63F Cell ID (G11~G24).xlsx")
df.drop_duplicates()
display(df)
# Out:
#                LOT        CELL
# 0       UA3AG115CA  UAGB5A0001
# 1       UA3AG115CA  UAGB5A0002
# 2       UA3AG115CA  UAGB5A0003
# 3       UA3AG115CA  UAGB5A0004
# 4       UA3AG115CA  UAGB5A0005
# ...            ...         ...
# 946767  UA3AG249C2  UAGP928721
# 946768  UA3AG249C2  UAGP928722
# 946769  UA3AG249C2  UAGP928723
# 946770  UA3AG249C2  UAGP928724
# 946771  UA3AG249C2  UAGP928725
#
# [946772 rows x 2 columns]

# %%
df['LOT'].drop_duplicates()
# Out:
# 0         UA3AG115CA
# 6222      UA3AG19ACB
# 15707     UA3AG19ACA
# 24550     UA3AG19AC2
# 33999     UA3AG19AC1
#              ...
# 915049    UA3AG235CB
# 925062    UA3AG245CB
# 928266    UA3AG245CC
# 932054    UA3AG249C1
# 938083    UA3AG249C2
# Name: LOT, Length: 116, dtype: object

# %%
df1 = df['LOT'].drop_duplicates()

df1.to_csv('1.csv')

# %%
df['CELL'].drop_duplicates()
# Out:
# 0         UAGB5A0001
# 1         UAGB5A0002
# 2         UAGB5A0003
# 3         UAGB5A0004
# 4         UAGB5A0005
#              ...
# 946767    UAGP928721
# 946768    UAGP928722
# 946769    UAGP928723
# 946770    UAGP928724
# 946771    UAGP928725
# Name: CELL, Length: 946772, dtype: object
